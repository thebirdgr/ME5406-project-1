# %%
import gym
from gym import wrappers
from gym import envs
import pprint
import plotting

# %%
env = gym.make('FrozenLake-v1')
# env = gym.make('MountainCar-v0', new_step_api=True)
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
env.reset()
print('Action space {}'.format(env.action_space))
print('State space {}'.format(env.observation_space))
pp = pprint.PrettyPrinter(indent=4)
# Out:
# Action space Discrete(4)
# State space Discrete(16)

# %%
pp.pprint(env.P[0])
# outputs {action: [probability (next_state), next_state, reward, done]}
#  Left, Down, Right and Up and (corresponding to numbers 0, 1, 2 and 3).
# Out:
# {   0: [   (0.3333333333333333, 0, 0.0, False),
#            (0.3333333333333333, 0, 0.0, False),
#            (0.3333333333333333, 4, 0.0, False)],
#     1: [   (0.3333333333333333, 0, 0.0, False),
#            (0.3333333333333333, 4, 0.0, False),
#            (0.3333333333333333, 1, 0.0, False)],
#     2: [   (0.3333333333333333, 4, 0.0, False),
#            (0.3333333333333333, 1, 0.0, False),
#            (0.3333333333333333, 0, 0.0, False)],
#     3: [   (0.3333333333333333, 1, 0.0, False),
#            (0.3333333333333333, 0, 0.0, False),
#            (0.3333333333333333, 0, 0.0, False)]}

# %%
pp.pprint(env.P[14])
# Out:
# {   0: [   (0.3333333333333333, 10, 0.0, False),
#            (0.3333333333333333, 13, 0.0, False),
#            (0.3333333333333333, 14, 0.0, False)],
#     1: [   (0.3333333333333333, 13, 0.0, False),
#            (0.3333333333333333, 14, 0.0, False),
#            (0.3333333333333333, 15, 1.0, True)],
#     2: [   (0.3333333333333333, 14, 0.0, False),
#            (0.3333333333333333, 15, 1.0, True),
#            (0.3333333333333333, 10, 0.0, False)],
#     3: [   (0.3333333333333333, 15, 1.0, True),
#            (0.3333333333333333, 10, 0.0, False),
#            (0.3333333333333333, 13, 0.0, False)]}

# %%
env.reset()
env.render()
new_state, r, done, info = env.step(1)
# step takes the indexed action

print('newstate {}'.format(new_state))
print('reward {}'.format(r))
print('done {}'.format(done))
print()
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# newstate 4
# reward 0.0
# done False
#
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
# This is basic code to take a step without learning.

# %%
env.reset()

for i in range(40):
    # env.render()
    new_state, r, done, info = env.step(env.action_space.sample())
    # pp.pprint(env.P[new_state])
    if done: # done is used for both failed case and success case
        print("Episode finished after {} timesteps".format(i+1))
        env.render() 
        break
    # print('Observation : ' + str(new_state))
    # print('Reward      : ' + str(r))
    # print('Done        : ' + str(done))
    # print('---------------------')
    # print(env.s) # this is the current state number
    # print(env.isd[env.s]) # isd is initial state distribution
env.close()
# Out:
# Episode finished after 3 timesteps
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG

# %%
# P is a dictionary of dictionary of lists
# P[s][a] == [(prob, next_state, reward, terminal), ...]
# I isd is a list or array of length nS
# isd == [0., 0., 1., 0.]

# %% [markdown]
# https://gist.github.com/artonge/0cebe66a00d2204c1fb1d0694c6ee014

# %%
import gym
from random import randint
import math
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

def learn(episodeCount):
    for i_episode in range(episodeCount):
        obs = env.reset()
        start = True

# Compute the decay of the exploration

# decayX = 0.02
# decayY = 20
# why are we doing max? is this the max value when taking an action from values?
# decay = max(-i_episode*decayX+decayY, 10/(i_episode+1))
# this is the monte carlo
        doEpisodeMC(obs, i_episode, start)



def doEpisodeMC(obs, i_episode, start):
    episodeStatesActions = []
    states_in_episode = []
    totalRewards = 0
    while(True):
        if start:
            action = np.random.choice([0,3])
            start=False
        else:
            action = policy[obs]
        next_state, reward, end, _ = env.step(action)
        print(next_state)
# state = getState(obs)  # Get the state
# action = policy(state, decay)  # Get the action
        episodeStatesActions.append({'state': obs, 'action': action, 'reward': reward})  # Save state and action to episodeStatesActions
# obs, reward, done, _ = env.step(action)  # Apply the action
        states_in_episode.append(obs)
        totalRewards += reward  # Update total reward for this episode
        if end:
            break
        obs = next_state

    for dicti in episodeStatesActions:
        first_occurence_idx = next(i for i,d in enumerate(episodeStatesActions) if d==dicti)
        print(episodeStatesActions)
        # new_val = (current_val * N + reward) / N + 1
        g = 0
        for event in episodeStatesActions:
            g += event['reward']
        returns_sum[d] += g
        returns_count[(st,act)] += 1.0
        Q[st][act] = returns_sum[(st,act)] / returns_count[(st,act)]

# @param state <string> the state to update
# @param action <int> the action to update
# @param G <int> the reward
# the third argument is the total rewards minus the enumeration, the more number of steps you've taken the lesser rewards is passed in
def updatePolicyMC(state, action, G):
    a = history[state][action]
# print(a)
# this is where you update the value or the policy
# new_val = (current_val * N + reward) / N + 1
# where N is the number of times the stae was visited
# meaning this position has quite a significant weightage in reaching the goal
# we find the average of the rewards
    a['value'] = (a['value'] * a['count'] + G) / (a['count'] + 1)
    a['count'] += 1


# @param obs <[float]> the observation to convert into a state
# @return the state associated to the observation_space
# If the set of observations where never met, create the state
# The function reduces the number of possible states
def getState(obs):
    state = ''
    state += str(math.floor(obs))
    return state


# @param state <string>
# @param decay <int>
# @return an action
# The policy progressivly stops exploration and gets greedy
# def policy(state, decay):
# 	# Get the less explored action and the most valued action
#     # you always first randomly sample the action space, the max valued action and the least explored action
# 	maxValueAction = env.action_space.sample()
# 	minCountAction = env.action_space.sample()
# 	if not state in history:  # If state does not existe, create it
# 		history[state] = []
# 		for _ in range(env.action_space.n):
#             history[state].append({'count':0, 'value':0})
#             # so the state has a list
#             # and for each action available in general, the state stores the number of times action taken and the value associated with it
# 			# exploring states we make sure to start the state values from 0

# 	stateValues = history[state] # get the action values for that state
# 	for action in range(env.action_space.n):
# 		if stateValues[maxValueAction]['value'] < stateValues[action]['value']: # see if the random action has a better value or the learnt one
# 			maxValueAction = action # take the higher valued action
# 		if stateValues[minCountAction]['count'] > stateValues[action]['count']: # see which one is the lesser explored action
# 			minCountAction = action # choose the action that was explored less
# 	# Computing the decay of the exploration
# 	if randint(0, 100) < decay: # depending on the decay value, btw the decay decreases with more episodes, you choose to explore or go with learning
# 		return minCountAction
# 	else:
# 		return maxValueAction


env = gym.make('FrozenLake-v1')
env.seed(123)
nbEpisodes = 1
stepsHistory = [0]*nbEpisodes

history = {}  # 'state' ==> [{'count': int, 'value': float}]
policy = defaultdict(int) 
returns_sum = defaultdict(float)
returns_count = defaultdict(float)
Q = defaultdict(lambda: np.zeros(env.action_space.n))
learn(nbEpisodes)

env.close()
plt.plot(range(nbEpisodes), stepsHistory, range(nbEpisodes), [195]*nbEpisodes)
plt.ylabel('Number of steps')
plt.show()
# Out:
# 0
# 0
# 0
# 4
# 8
# 12
# [{'state': 0, 'action': 3, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 4, 'action': 0, 'reward': 0.0}, {'state': 8, 'action': 0, 'reward': 0.0}]
# [{'state': 0, 'action': 3, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 4, 'action': 0, 'reward': 0.0}, {'state': 8, 'action': 0, 'reward': 0.0}]
# [{'state': 0, 'action': 3, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 4, 'action': 0, 'reward': 0.0}, {'state': 8, 'action': 0, 'reward': 0.0}]
# [{'state': 0, 'action': 3, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 4, 'action': 0, 'reward': 0.0}, {'state': 8, 'action': 0, 'reward': 0.0}]
# [{'state': 0, 'action': 3, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 4, 'action': 0, 'reward': 0.0}, {'state': 8, 'action': 0, 'reward': 0.0}]
# [{'state': 0, 'action': 3, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 0, 'action': 0, 'reward': 0.0}, {'state': 4, 'action': 0, 'reward': 0.0}, {'state': 8, 'action': 0, 'reward': 0.0}]

# %%
import gym
from random import randint
import math
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict# initiatlize:
# policy
policy = defaultdict(lambda: randint(0,3)) # initialize random actions to the start initital policy, lambda: 0
state_action_returns = defaultdict(lambda: 0)
state_action_count = defaultdict(lambda: 0) # since later we need the average, we need to make sure that we know how many times the state was visited, so as not to overbias with it's high values
Q = defaultdict(lambda: np.zeros(env.action_space.n))

n_episodes = 100

 # Reward schedule:
 #    - Reach goal(G): +1
 #    - Reach hole(H): -1
 #    - Reach frozen(F): 0
for i_episode in range(n_episodes):
    curr_state =  env.reset()
    start = True # for the starting taking a randoming action, to give us exploring starts, this so that whatever direction it takes, it can reach the goal
    state_action_returns_episode = [] # to track the Q(s,a) in each episode
    states_in_episode = [] # to track S in each episode
    while(True): # proceed until you reach you end goals
        if(start):
            action = np.random.choice([0,1,2,3])
            start=False
        else:
            action = policy[curr_state]
        next_state, reward, end, probability = env.step(action)
        if(next_state == 15):
            reward = 1
        elif(next_state in [5, 7, 11, 12]):
            reward = -1
        else:
            reward = 0
        state_action_returns_episode.append(((curr_state, action),reward)) # to match our state_action_returns
        states_in_episode.append(curr_state)
        if end:
            if(i_episode > 49950):
                print(reward)
                print("reached end goal in: ", len(states_in_episode))
            break
        curr_state = next_state
     
    # update the state-action pair values 
    for ((curr_state, action),reward) in state_action_returns_episode:
        first_occurence_idx = next(i for i,(s_a,r) in enumerate(state_action_returns_episode) if s_a==(curr_state,action))
        g = 0
        for event in state_action_returns_episode:
            # print(event)
            g += event[1] # at the first round rewards will be 0 as the goal is not reached and it's still exploring
        state_action_count[(curr_state, action)] += 1
        if(i_episode > 49950):
            print(state_action_returns[(curr_state, action)])
        # new_val = (current_val * N + reward) / N + 1
        state_action_returns[(curr_state, action)] += (state_action_returns[(curr_state, action)] * state_action_count[(curr_state, action)] + g) / (state_action_count[(curr_state, action)] + 1)
        Q[curr_state][action] = state_action_returns[(curr_state, action)]
        
    for curr_state in states_in_episode:
        # get all the curr_state values
        curr_state_action_pairs = [(s,a) for ((s,a),r) in state_action_returns_episode if s==curr_state]
        maximum = 0
        for pair in curr_state_action_pairs:
            if Q[pair[0]][pair[1]] > maximum:
                maximum = Q[pair[0]][pair[1]]
                policy[curr_state] = pair[1]
                
pp.pprint(Q)
pp.pprint(policy)
# Out:
# defaultdict(<function <lambda> at 0x00000186AF97C430>,
#             {   0: array([-4.79726963e+08, -2.14156179e+06, -1.46228314e+53, -5.60237368e+05]),
#                 1: array([ 0.00000000e+00, -1.10027847e+22,  0.00000000e+00,  0.00000000e+00]),
#                 2: array([ 0.00000000e+00,  0.00000000e+00, -2.10994378e+25,  0.00000000e+00]),
#                 3: array([-3.09401619e+15,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00]),
#                 4: array([ 0.00000000e+00,  0.00000000e+00, -8.63817467e+22,  0.00000000e+00]),
#                 6: array([        0.       ,         0.       ,         0.       ,
#        -16264038.1248231]),
#                 8: array([       0.        , -3968653.33308082,        0.        ,
#               0.        ]),
#                 9: array([    0.        ,     0.        ,     0.        , -1915.27734352]),
#                 10: array([ 0.   ,  0.   , -1.325,  0.   ]),
#                 14: array([0.        , 1.16666667, 0.        , 0.        ])})
# defaultdict(<function <lambda> at 0x00000186AF900820>,
#             {   0: 2,
#                 1: 1,
#                 2: 2,
#                 3: 0,
#                 4: 2,
#                 6: 3,
#                 8: 1,
#                 9: 3,
#                 10: 2,
#                 14: 1})

# %%
def plot_value_function(V, title="Value Function"):
    """
    Plots the value function as a surface plot.
    """
    
    # print([pair for k in V.keys() for pair in V[k]])
    # print([pair for k in V.keys() for pair in V[k]])
    print(V)
    min_x = min(k[0] for k in V.keys())
    max_x = max(k[0] for k in V.keys())
    min_y = min(k[1] for k in V.keys())
    max_y = max(k[1] for k in V.keys())


    x_range = np.arange(min_x, max_x + 1)
    y_range = np.arange(min_y, max_y + 1)
    X, Y = np.meshgrid(x_range, y_range)

    # Find value for all (x, y) coordinates
    Z_noace = np.apply_along_axis(lambda _: V[(_[0], _[1], False)], 2, np.dstack([X, Y]))
    Z_ace = np.apply_along_axis(lambda _: V[(_[0], _[1], True)], 2, np.dstack([X, Y]))

    def plot_surface(X, Y, Z, title):
        fig = plt.figure(figsize=(20, 10))
        ax = fig.add_subplot(111, projection='3d')
        surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                               cmap=matplotlib.cm.coolwarm, vmin=-1.0, vmax=1.0)
        ax.set_xlabel('Player Sum')
        ax.set_ylabel('Dealer Showing')
        ax.set_zlabel('Value')
        ax.set_title(title)
        ax.view_init(ax.elev, -120)
        fig.colorbar(surf)
        plt.show()

    plot_surface(X, Y, Z_noace, "{} (No Usable Ace)".format(title))
    plot_surface(X, Y, Z_ace, "{} (Usable Ace)".format(title))
    
V = defaultdict(float)
print(Q.items())
for state, actions in Q.items():
    action_value = np.max(actions)
    V[state] = action_value

plot_value_function(V, title="Optimal Value Function")
# Out:
# dict_items([(0, array([0., 0., 0., 0.])), (1, array([0., 0., 0., 0.])), (4, array([0., 0., 0., 0.])), (8, array([0., 0., 0., 0.])), (9, array([0., 0., 0., 0.])), (10, array([0., 0., 0., 0.])), (13, array([0., 0., 0., 0.])), (14, array([0.        , 0.00108696, 0.        , 0.        ])), (6, array([0., 0., 0., 0.]))])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [36], line 45
#      42     action_value = np.max(actions)
#      43     V[state] = action_value
# ---> 45 plot_value_function(V, title="Optimal Value Function")
#
# Cell In [36], line 9, in plot_value_function(V, title)
#       2 """
#       3 Plots the value function as a surface plot.
#       4 """
#       6 # print([pair for k in V.keys() for pair in V[k]])
#       7 # print([pair for k in V.keys() for pair in V[k]])
#       8 # print(V)
# ----> 9 min_x = min(k[0] for k in V.keys())
#      10 max_x = max(k[0] for k in V.keys())
#      11 min_y = min(k[1] for k in V.keys())
#
# Cell In [36], line 9, in <genexpr>(.0)
#       2 """
#       3 Plots the value function as a surface plot.
#       4 """
#       6 # print([pair for k in V.keys() for pair in V[k]])
#       7 # print([pair for k in V.keys() for pair in V[k]])
#       8 # print(V)
# ----> 9 min_x = min(k[0] for k in V.keys())
#      10 max_x = max(k[0] for k in V.keys())
#      11 min_y = min(k[1] for k in V.keys())
#
# TypeError: 'int' object is not subscriptable

# %%
# env.reset()
# a, b, c, d = env.step(3)
# print(a, b, c, d)

# %%
from typing import List

# DFS to check that it's a valid path.
def is_valid(board: List[List[str]], max_size: int) -> bool:
    frontier, discovered = [], set()
    frontier.append((0, 0))
    while frontier:
        r, c = frontier.pop()
        if not (r, c) in discovered:
            discovered.add((r, c))
            directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]
            for x, y in directions:
                r_new = r + x
                c_new = c + y
                if r_new < 0 or r_new >= max_size or c_new < 0 or c_new >= max_size:
                    continue
                if board[r_new][c_new] == "G":
                    return True
                if board[r_new][c_new] != "H":
                    frontier.append((r_new, c_new))
    return False
def generate_random_map(size: int = 8, p: float = 0.8) -> List[str]:
    """Generates a random valid map (one that has a path from start to goal)
    Args:
        size: size of each side of the grid
        p: probability that a tile is frozen
    Returns:
        A random valid map
    """
    valid = False
    board = []  # initialize to make pyright happy

    while not valid:
        p = min(1, p)
        board = np.random.choice(["F", "H"], (size, size), p=[p, 1 - p])
        board[0][0] = "S"
        board[-1][-1] = "G"
        valid = is_valid(board, size)
    return ["".join(x) for x in board]
pp = pprint.PrettyPrinter(indent=10)

# %%
# sarsa implementation
import gym
from random import randint
import math
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict # initiatlize:

env = gym.make('FrozenLake-v1')
env.render()

# check to see if you can tune these values and how to tune them
alpha = 0.1
epsilon = 0.1
discount_rate = 0.9

Q = defaultdict(lambda: np.zeros(env.action_space.n))
# print(env.observation_space.n)
policy = defaultdict(lambda: 0)
state = defaultdict(lambda: 0)

n_episodes = 100

max_steps = 100

def choose_action_sarsa(state):
    action = 0 # initiate arbitary action
    p = np.random.random()
    if p < epsilon:
        # print('ep')
        action = env.action_space.sample()
    else:
        # print("max")
        action = np.argmax(Q[(state, action)])
        # action = np.argmax((st, act) for )
    return action

for i_episode in range(n_episodes):
    state =  env.reset()
    # if the action state action does not exist, we create it, else use the existing ones
    # if state not in policy:
    # for a in range(env.action_space.n):
    #         Q[(state, a)]
    action = choose_action_sarsa(state)
    count = 0
    while(True):
        # take action, observe reward and next state
        next_state, reward, end, probability = env.step(action)
        # choose the action for the next state as well using the policy from Q
        next_state_action = choose_action_sarsa(next_state)
        if(next_state == 15):
            reward = 1
        elif(next_state in [5, 7, 11, 12]):
            reward = -1
        else:
            reward = 0
        Q[(state, action)] = Q[(state, action)] + alpha * (reward + discount_rate * Q[(next_state, next_state_action)] - Q[(state, action)])
        count += 1
        if end or (count > max_steps):
            # print("Reached goal in steps: ", count)
            break
        state = next_state
        action = next_state_action
    
    # print(Q)
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
# Q-Learning implementation
import gym
from random import randint
import math
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict # initiatlize:

env = gym.make('FrozenLake-v1')
env.render()

# check to see if you can tune these values and how to tune them
alpha = 0.1
epsilon = 0.1
discount_rate = 0.9

Q = defaultdict(lambda: np.zeros(env.action_space.n))
# print(env.observation_space.n)
policy = defaultdict(lambda: 0)
state = defaultdict(lambda: 0)

def choose_action_q_learning(state):
    action = 0 # initiate arbitary action
    p = np.random.random()
    if p < epsilon:
        # print('ep')
        action = env.action_space.sample()
    else:
        # print("max")
        action = np.argmax(Q[(state, action)])
        # action = np.argmax((st, act) for )
    return action

n_episodes = 1000

max_steps = 200

for i_episode in range(n_episodes):
    state = env.reset()
    count = 0
    while(True):
        # choose A from S using policy derived from Q
        action =  choose_action_q_learning(state)
        # take action A, observe reward and next state
        next_state, reward, end, probability = env.step(action)
        count += 1
        if(next_state == 15):
            reward = 1
        elif(next_state in [5, 7, 11, 12]):
            reward = -1
        else:
            reward = 0
        Q[(state, action)] = Q[(state, action)] + alpha * (reward + discount_rate * np.argmax(Q[(next_state, action)]) - Q[(state, action)])
        if end or (count > max_steps):
            # print("Reaching steps in: ", count)
            break
        state = next_state
        
        
pp.pprint(Q)
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# defaultdict(<function <lambda> at 0x000002830C5EAEE0>,
#             {         (0, 0): array([0., 0., 0., 0.]),
#                       (0, 1): array([0., 0., 0., 0.]),
#                       (0, 2): array([0., 0., 0., 0.]),
#                       (0, 3): array([0., 0., 0., 0.]),
#                       (1, 0): array([-0.35573745, -0.35573745, -0.35573745, -0.35573745]),
#                       (1, 1): array([-0.1629, -0.1629, -0.1629, -0.1629]),
#                       (1, 2): array([-0.0531441, -0.0531441, -0.0531441, -0.0531441]),
#                       (1, 3): array([0., 0., 0., 0.]),
#                       (2, 0): array([0., 0., 0., 0.]),
#                       (2, 1): array([0., 0., 0., 0.]),
#                       (2, 2): array([0., 0., 0., 0.]),
#                       (2, 3): array([0., 0., 0., 0.]),
#                       (4, 0): array([0., 0., 0., 0.]),
#                       (4, 1): array([-0.21788337, -0.21788337, -0.21788337, -0.21788337]),
#                       (4, 2): array([-0.15922741, -0.15922741, -0.15922741, -0.15922741]),
#                       (4, 3): array([-0.54980901, -0.54980901, -0.54980901, -0.54980901]),
#                       (5, 0): array([0., 0., 0., 0.]),
#                       (5, 1): array([0., 0., 0., 0.]),
#                       (5, 2): array([0., 0., 0., 0.]),
#                       (5, 3): array([0., 0., 0., 0.]),
#                       (6, 0): array([-0.059049, -0.059049, -0.059049, -0.059049]),
#                       (6, 2): array([0., 0., 0., 0.]),
#                       (8, 0): array([-0.34447952, -0.34447952, -0.34447952, -0.34447952]),
#                       (8, 1): array([-0.36697988, -0.36697988, -0.36697988, -0.36697988]),
#                       (8, 2): array([-0.37853021, -0.37853021, -0.37853021, -0.37853021]),
#                       (8, 3): array([0., 0., 0., 0.]),
#                       (9, 0): array([-0.41845544, -0.41845544, -0.41845544, -0.41845544]),
#                       (9, 1): array([0., 0., 0., 0.]),
#                       (9, 2): array([-0.1, -0.1, -0.1, -0.1]),
#                       (9, 3): array([0., 0., 0., 0.]),
#                       (10, 0): array([0., 0., 0., 0.]),
#                       (10, 1): array([0., 0., 0., 0.]),
#                       (12, 0): array([0., 0., 0., 0.]),
#                       (12, 1): array([0., 0., 0., 0.]),
#                       (12, 2): array([0., 0., 0., 0.]),
#                       (13, 0): array([-0.17247914, -0.17247914, -0.17247914, -0.17247914]),
#                       (13, 1): array([-0.1, -0.1, -0.1, -0.1]),
#                       (13, 2): array([0., 0., 0., 0.])})

# %% [markdown]
# 10 x 10 version from here

# %%
import gym
from random import randint
import math
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict # initiatlize:

env = gym.make('FrozenLake-v1', desc=generate_random_map(size=10, p = 0.75))
env.render()

# policy
policy = defaultdict(lambda: randint(0,3)) # initialize random actions to the start initital policy, lambda: 0
state_action_returns = defaultdict(lambda: 0)
state_action_count = defaultdict(lambda: 0) # since later we need the average, we need to make sure that we know how many times the state was visited, so as not to overbias with it's high values
Q = defaultdict(lambda: np.zeros(env.action_space.n))
pp = pprint.PrettyPrinter(indent=4)

n_episodes = 10000

 # Reward schedule:
 #    - Reach goal(G): +1
 #    - Reach hole(H): -1
 #    - Reach frozen(F): 0
for i_episode in range(n_episodes):
    curr_state =  env.reset()
    start = True # for the starting taking a randoming action, to give us exploring starts, this so that whatever direction it takes, it can reach the goal
    state_action_returns_episode = [] # to track the Q(s,a) in each episode
    states_in_episode = [] # to track S in each episode
    while(True): # proceed until you reach you end goals
        if(start):
            action = np.random.choice([0,1,2,3])
            start=False
        else:
            action = policy[curr_state]
        next_state, reward, end, probability = env.step(action)
        if(env.desc[next_state//10][next_state%10] == b"G"):
            reward = 1
        elif(env.desc[next_state//10][next_state%10] == b"H"): # need to add the holes
            reward = -1
        else:
            reward = 0
        state_action_returns_episode.append(((curr_state, action),reward)) # to match our state_action_returns
        states_in_episode.append(curr_state)
        if end:
            if(i_episode >= (n_episodes - 2)):
                print(reward)
                print("reached end goal in: ", len(states_in_episode))
            break
        curr_state = next_state
     
    # update the state-action pair values 
    for ((curr_state, action),reward) in state_action_returns_episode:
        first_occurence_idx = next(i for i,(s_a,r) in enumerate(state_action_returns_episode) if s_a==(curr_state,action))
        g = 0
        for event in state_action_returns_episode:
            # print(event)
            g += event[1] # at the first round rewards will be 0 as the goal is not reached and it's still exploring
        state_action_count[(curr_state, action)] += 1
        # if(i_episode > n_episodes - 2):
        #     print(state_action_returns[(curr_state, action)])
        # new_val = (current_val * N + reward) / N + 1
        state_action_returns[(curr_state, action)] += (state_action_returns[(curr_state, action)] * state_action_count[(curr_state, action)] + g) / (state_action_count[(curr_state, action)] + 1)
        Q[curr_state][action] = state_action_returns[(curr_state, action)]
        
    for curr_state in states_in_episode:
        # get all the curr_state values
        curr_state_action_pairs = [(s,a) for ((s,a),r) in state_action_returns_episode if s==curr_state]
        maximum = 0
        for pair in curr_state_action_pairs:
            if Q[pair[0]][pair[1]] > maximum:
                maximum = Q[pair[0]][pair[1]]
                policy[curr_state] = pair[1]
                
pp.pprint(Q)
# pp.pprint(policy)
# Out:
# SFFFHFFFHF
# FFFFFFFFFF
# FFHFFFFHFH
# FFFFFFHFHF
# FHFHFFFFFF
# HFFFFFHFHF
# FFFHFFHFFF
# FFFHFFHHHH
# FFFFFFHFFF
# FFFFFFFFHG
# -1
# reached end goal in:  8
# -1
# reached end goal in:  39
# defaultdict(<function <lambda> at 0x000001E5A0CF2040>,
#             {   0: array([-inf, -inf, -inf, -inf]),
#                 1: array([  0.,   0., -inf,   0.]),
#                 2: array([-inf,   0.,   0.,   0.]),
#                 3: array([  0.,   0.,   0., -inf]),
#                 10: array([  0., -inf,   0.,   0.]),
#                 11: array([  0.,   0.,   0., -inf]),
#                 12: array([  0.,   0., -inf,   0.]),
#                 13: array([  0.,   0., -inf,   0.]),
#                 14: array([  0.,   0.,   0., -inf]),
#                 15: array([  0., -inf,   0.,   0.]),
#                 16: array([ 0.00000000e+000, -6.43559577e+165,  0.00000000e+000,
#         0.00000000e+000]),
#                 17: array([ 0.00000000e+00, -2.90535628e+65,  0.00000000e+00,  0.00000000e+00]),
#                 18: array([-5.17452263e+27,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00]),
#                 20: array([  0.,   0., -inf,   0.]),
#                 21: array([  0.,   0., -inf,   0.]),
#                 23: array([-inf,   0.,   0.,   0.]),
#                 25: array([ 0.00000000e+000,  0.00000000e+000, -7.75959003e+201,
#         0.00000000e+000]),
#                 26: array([-1.33720987e+123,  0.00000000e+000,  0.00000000e+000,
#         0.00000000e+000]),
#                 28: array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -1.86367878e+09]),
#                 30: array([  0.,   0., -inf,   0.]),
#                 31: array([-inf,   0.,   0.,   0.]),
#                 33: array([ 0.00000000e+000,  0.00000000e+000, -7.59084131e+238,
#         0.00000000e+000]),
#                 34: array([ 0.0000000e+000, -1.8070833e+140,  0.0000000e+000,  0.0000000e+000]),
#                 35: array([-3.39075084e+125,  0.00000000e+000,  0.00000000e+000,
#         0.00000000e+000]),
#                 37: array([   0.        , -724.61384503,    0.        ,    0.        ]),
#                 39: array([ 0. ,  0. , -0.5,  0. ]),
#                 40: array([  0.,   0.,   0., -inf]),
#                 44: array([-2.30615345e+60,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00]),
#                 45: array([ 0.0000000e+00,  0.0000000e+00, -5.8015588e+56,  0.0000000e+00]),
#                 46: array([ 0.0000000e+00, -7.0595408e+20,  0.0000000e+00,  0.0000000e+00]),
#                 47: array([ 0.00000000e+00,  0.00000000e+00, -2.43553689e+08,  0.00000000e+00]),
#                 48: array([    0.        ,     0.        , -1397.54098685,     0.        ]),
#                 49: array([-15.17797619,   0.        ,   0.        ,   0.        ]),
#                 52: array([ 0. , -0.5,  0. ,  0. ]),
#                 53: array([ 0. ,  0. , -0.5,  0. ]),
#                 54: array([ 0.00000000e+00,  0.00000000e+00, -3.41352253e+23,  0.00000000e+00]),
#                 55: array([ 0.00000000e+00,  0.00000000e+00, -3.21403143e+29,  0.00000000e+00]),
#                 57: array([   0.        , -196.52653883,    0.        ,    0.        ]),
#                 59: array([ 0. , -0.5,  0. ,  0. ]),
#                 62: array([ 0. ,  0. , -0.5,  0. ]),
#                 64: array([-5.1148782e+13,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00]),
#                 65: array([-2.82586773e+10,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00]),
#                 67: array([ 0.        , -8.09583333,  0.        ,  0.        ]),
#                 68: array([ 0.        , -2.29166667,  0.        ,  0.        ]),
#                 69: array([ 0.        , -2.29166667,  0.        ,  0.        ]),
#                 70: array([ 0.        , -8.09583333,  0.        ,  0.        ]),
#                 71: array([   0.        , -102.89485367,    0.        ,    0.        ]),
#                 72: array([-2.29166667,  0.        ,  0.        ,  0.        ]),
#                 74: array([      0.        , -560237.36788805,       0.        ,
#              0.        ]),
#                 75: array([     0.       ,      0.       , -38480.6069842,      0.       ]),
#                 80: array([ 0.        ,  0.        , -2.29166667,  0.        ]),
#                 81: array([    0.        ,     0.        , -5235.14727989,     0.        ]),
#                 82: array([-196.52653883,    0.        ,    0.        ,    0.        ]),
#                 83: array([   0.        ,    0.        ,    0.        , -196.52653883]),
#                 84: array([-75037.23361919,      0.        ,      0.        ,      0.        ]),
#                 85: array([-376.75919942,    0.        ,    0.        ,    0.        ]),
#                 87: array([ 0. , -0.5,  0. ,  0. ]),
#                 90: array([-2.29166667,  0.        ,  0.        ,  0.        ]),
#                 91: array([-54.10255456,   0.        ,   0.        ,   0.        ]),
#                 92: array([-4.325,  0.   ,  0.   ,  0.   ]),
#                 94: array([  0.        ,   0.        , -28.58370536,   0.        ]),
#                 95: array([ 0.   ,  0.   , -4.325,  0.   ]),
#                 96: array([  0.        ,   0.        , -28.58370536,   0.        ]),
#                 97: array([-8.09583333,  0.        ,  0.        ,  0.        ])})

# %%
# 10 x 10 Sarsa version
import gym
from random import randint
import math
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict # initiatlize:

env = gym.make('FrozenLake-v1', desc=generate_random_map(size=10, p = 0.75))
env.render()

# check to see if you can tune these values and how to tune them
alpha = 0.1
epsilon = 0.1
discount_rate = 0.9

Q = defaultdict(lambda: np.zeros(env.action_space.n))
# print(env.observation_space.n)
policy = defaultdict(lambda: 0)
state = defaultdict(lambda: 0)

n_episodes = 100

max_steps = 100

def choose_action_sarsa(state):
    action = 0 # initiate arbitary action
    p = np.random.random()
    if p < epsilon:
        # print('ep')
        action = env.action_space.sample()
    else:
        # print("max")
        action = np.argmax(Q[(state, action)])
        # action = np.argmax((st, act) for )
    return action

for i_episode in range(n_episodes):
    state =  env.reset()
    # if the action state action does not exist, we create it, else use the existing ones
    # if state not in policy:
    # for a in range(env.action_space.n):
    #         Q[(state, a)]
    action = choose_action_sarsa(state)
    count = 0
    while(True):
        # take action, observe reward and next state
        next_state, reward, end, probability = env.step(action)
        # print(f'Going from {state} to {next_state}')
        # choose the action for the next state as well using the policy from Q
        next_state_action = choose_action_sarsa(next_state)
        if(env.desc[next_state//10][next_state%10] == b"G"):
            reward = 1
        elif(env.desc[next_state//10][next_state%10] == b"H"): # need to add the holes
            reward = -1
        else:
            reward = 0
        Q[(state, action)] = Q[(state, action)] + alpha * (reward + discount_rate * Q[(next_state, next_state_action)] - Q[(state, action)])
        count += 1
        if end or (count > max_steps):
            # print("Reached goal in steps: ", count)
            break
        state = next_state
        action = next_state_action
    
    print(Q)
# Out:
# SFFFHFFFFF
# FFFFHHFFFH
# FFHHFFFFFF
# FFFFFHFFFF
# FFFFHFFFFH
# HFHFHFFFFF
# FFFFFFFFFF
# FHFFHFFFFF
# FHFHFFFFFF
# FFHFFFFFFG
# defaultdict(<function <lambda> at 0x000002834463EDC0>, {(0, 0): array([0., 0., 0., 0.]), (0, 2): array([0., 0., 0., 0.]), (10, 3): array([0., 0., 0., 0.]), (11, 0): array([0., 0., 0., 0.]), (1, 0): array([0., 0., 0., 0.]), (10, 0): array([0., 0., 0., 0.]), (20, 0): array([0., 0., 0., 0.]), (30, 0): array([0., 0., 0., 0.]), (40, 0): array([-0.1, -0.1, -0.1, -0.1]), (50, 0): array([0., 0., 0., 0.])})
# defaultdict(<function <lambda> at 0x000002834463EDC0>, {(0, 0): array([0., 0., 0., 0.]), (0, 2): array([0., 0., 0., 0.]), (10, 3): array([0., 0., 0., 0.]), (11, 0): array([0., 0., 0., 0.]), (1, 0): array([0., 0., 0., 0.]), (10, 0): array([-0.00022702, -0.00022702, -0.00022702, -0.00022702]), (20, 0): array([-0.00346183, -0.00346183, -0.00346183, -0.00346183]), (30, 0): array([-0.01707322, -0.01707322, -0.01707322, -0.01707322]), (40, 0): array([-0.06874542, -0.06874542, -0.06874542, -0.06874542]), (50, 0): array([0., 0., 0., 0.]), (0, 3): array
, -0.06622743, -0.06622743, -0.06622743]), (40, 2): array([-0.14063484, -0.14063484, -0.14063484, -0.14063484]), (41, 0): array([-0.22013493, -0.22013493, -0.22013493, -0.22013493]), (31, 0): array([-0.12667101, -0.12667101, -0.12667101, -0.12667101]), (30, 1): array([-0.13395754, -0.13395754, -0.13395754, -0.13395754]), (0, 1): array([-0.04862851, -0.04862851, -0.04862851, -0.04862851]), (20, 1): array([-0.15534742, -0.15534742, -0.15534742, -0.15534742]), (10, 1): array([-0.09296788, -0.09296788, -0.09296788, -0.09296788]), (21, 0): array([-0.09979251, -0.09979251, -0.09979251, -0.09979251]), (30, 3): array([-0.099415, -0.099415, -0.099415, -0.099415]), (20, 2): array([-0.10057831, -0.10057831, -0.10057831, -0.10057831]), (20, 3): array([-0.04350642, -0.04350642, -0.04350642, -0.04350642]), (30, 2): array([-0.19740213, -0.19740213, -0.19740213, -0.19740213]), (40, 1): array([-0.36008086, -0.36008086, -0.36008086, -0.36008086]), (51, 1): array([-0.19, -0.19, -0.19, -0.19]), (52, 2): array([0., 0., 0., 0.]), (21, 3): array([-0.19, -0.19, -0.19, -0.19]), (22, 0): array([0., 0., 0., 0.]), (11, 1): array([-0.01209328, -0.01209328, -0.01209328, -0.01209328]), (31, 1): array([-0.02671343, -0.02671343, -0.02671343, -0.02671343]), (40, 3): array([-0.07966786, -0.07966786, -0.07966786, -0.07966786]), (50, 3): array([0., 0., 0., 0.]), (50, 1): array([0., 0., 0., 0.]), (1, 2): array([0., 0., 0., 0.]), (2, 0): array([-0.00679143, -0.00679143, -0.00679143, -0.00679143]), (12, 0): array([-0.09042576, -0.09042576, -0.09042576, -0.09042576]), (51, 0): array([-0.00011123, -0.00011123, -0.00011123, -0.00011123]), (52, 0): array([0., 0., 0., 0.]), (21, 1): array([-0.02794867, -0.02794867, -0.02794867, -0.02794867]), (50, 2): array([0., 0., 0., 0.]), (11, 2): array([-0.01310709, -0.01310709, -0.01310709, -0.01310709]), (1, 3): array([-0.00582122, -0.00582122, -0.00582122, -0.00582122]), (11, 3): array([0., 0., 0., 0.]), (12, 2): array([0., 0., 0., 0.]), (13, 3): array([0., 0., 0., 0.]), (3, 0): array([0., 0., 0., 0.]), (13, 0): array([0., 0., 0., 0.]), (41, 2): array([-0.0107707, -0.0107707, -0.0107707, -0.0107707])})

# %%
# Q-learning
import gym
from random import randint
import math
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict # initiatlize:

env = gym.make('FrozenLake-v1', desc=generate_random_map(size=10, p = 0.75))
env.render()

# check to see if you can tune these values and how to tune them
alpha = 0.5
epsilon = 0.8
discount_rate = 0.9

Q_list = []
# Q = defaultdict(lambda: np.zeros(env.action_space.n))
# print(env.observation_space.n)
policy = defaultdict(lambda: 0)
state = defaultdict(lambda: 0)

def choose_action_q_learning(Q, state, decay):
    
    min_action = env.action_space.sample() # initiate arbitary action
    max_action = env.action_space.sample()
    for action in range(env.action_space.n):
        if Q[(state, max_action)]["a"] < Q[(state, action)]["a"]:
            max_action = action
        # if Q[(state, min_action)]["c"] < Q[(state, action)]["c"]:
        #     min_action = action
    if np.random.random() < decay:
        return min_action # lesser explored
    else:
        return max_action # exploitation

# def choose_action_q_learning(state):
#     action = 0 # initiate arbitary action
#     p = np.random.random()
#     if p < epsilon:
#         # print('ep')
#         action = env.action_space.sample()
#     else:
#         # print("max")
#         action = np.argmax(Q[(state, action)])
#         # action = np.argmax((st, act) for )
#     return action

# n_episodes = 100000
# , desc=generate_random_map(size=10, p = 0.75)
max_steps = 200

steps_per_episode = []
steps_per_episode_goal = []
size = int(math.sqrt(env.observation_space.n))

for n_episodes in range(0, 1000000, 100000):
    
    # Q = defaultdict(lambda: np.zeros(env.action_space.n))
    # Q = defaultdict(lambda: 0)
    Q = defaultdict(lambda: {"a": 0, "c": 0}) # action value and the count
    decayX = -0.0000000125
    # init_alpha = 0.01
    init_epsilon = 0.8
    
    for i_episode in range(n_episodes):
        
        epsilon = init_epsilon + decayX*i_episode
        
        # if i_episode / 1000 > 21:
        #     epsilon = 0.1

        state = env.reset()
        count = 0
        while(True):
            # choose A from S using policy derived from Q
            action =  choose_action_q_learning(Q, state, epsilon)
            # take action A, observe reward and next state
            next_state, reward, end, probability = env.step(action)
            count += 1 # steps
            if(env.desc[next_state//size][next_state%size] == b"G"):
                # print(len(steps_per_episode_goal))
                reward = 1
            elif(env.desc[next_state//size][next_state%size] == b"H"): # need to add the holes
                reward = -1
            else:
                reward = 0
            Q[(state, action)]["a"] = Q[(state, action)]["a"] + alpha * (reward + discount_rate * np.argmax(Q[(state, action)]["a"] - Q[(state, action)]["a"]))
            Q[(state, action)]["c"] += 1 # number of time the state action was visited                         
            if end: # don't include max_steps first
                # print("Reaching steps in: ", count)
                if(env.desc[next_state//size][next_state%size] == b"G"):
                    steps_per_episode_goal.append((i_episode, count))
                    # print("goal")
                else:
                    steps_per_episode.append((i_episode, count))
                break
            state = next_state
        if(i_episode % 100000 == 0):
                print("Per episode", i_episode)
                
    Q_list.append(Q) # get the policies for comparison
        
        
# pp.pprint(Q)
print("Finished")
# Out:
# SFFFFFFHFF
# FFFFFFFFFF
# FFFFHFFFFH
# FFFFFFHFFF
# FHFFHHHFHF
# HFFFFFFFFF
# FFFHHFFFFF
# FHFFHFFHFF
# FFHFFFFHHF
# FFFFFFFHFG
# Per episode 0
# Per episode 0
# Per episode 100000
# Per episode 0
# Per episode 100000
# Per episode 200000
# Per episode 0
# Per episode 100000
# Per episode 200000
# Per episode 300000
# Per episode 0
# Per episode 100000
# Per episode 200000
# Per episode 300000
# Per episode 400000
# Per episode 0
# Per episode 100000
# Per episode 200000
# Per episode 300000
# Per episode 400000
# Per episode 500000
# Per episode 0
# Per episode 100000
# Per episode 200000
# Per episode 300000
# Per episode 400000
# Per episode 500000
# Per episode 600000
# Per episode 0
# Per episode 100000
# Per episode 200000
# Per episode 300000
# Per episode 400000
# Per episode 500000
# Per episode 600000
# Per episode 700000
# Per episode 0
# Per episode 100000
# Per episode 200000
# Per episode 300000
# Per episode 400000
# Per episode 500000
# Per episode 600000
# Per episode 700000
# Per episode 800000

# %%
print(len(steps_per_episode_goal))
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
plt.subplots_adjust(left=0.4, bottom=None, right=None, top=None, wspace=None, hspace=0.2)
plt.plot(*zip(*steps_per_episode), 'o')
plt.plot(*zip(*steps_per_episode_goal), 'x', color="r")
plt.show()
# print(Q_list[4])
# Out:
# 0

# %% [markdown]
# changing_no_of_episodes (0-100000, 10000)
#
# - alpha = 0.4
# - epsilon = 0.2
# - discount_rate = 1
#
# changing_alpha_rate (0-1, 0.1)
#
# - n_episodes = 100000
# - epsilon = 0.2
# - discount_rate = 1
#
#
# changing_epsilon_rate(0 - 1, 0.1)
#
# - n_episodes = 100000
# - alpha = 0.4
# - discount_rate = 1

# %%
# Evaluating the Q-learning policy

cores = len(Q_list)

print(cores)
subplot_size = math.ceil(math.sqrt(cores))

figure, axis = plt.subplots(subplot_size, subplot_size)

plt.rcParams["figure.figsize"] = (30,20)

curve = np.array([1,2,3,4,5])



for r in range(cores):
    
    end_list = []
    steps_goal = []
    steps_end = []

    for i in range(1000):
        state = env.reset()
        steps = 0
        size = int(math.sqrt(env.observation_space.n))
        done = False
        while not done:
            max_action = env.action_space.sample()
            for action in range(env.action_space.n):
                if Q[(state, max_action)]["a"] < Q[(state, action)]["a"]:
                    max_action = action

            next_state, reward, done, info = env.step(max_action)
            steps += 1
            if(env.desc[next_state//size][next_state%size] == b"G"):
                # print(len(steps_per_episode_goal))
                # print("Steps to reach goal: ", steps)
                steps_goal.append(steps)
                reward = 1
            elif(env.desc[next_state//size][next_state%size] == b"H"): # need to add the holes
                # print("Steps to reach hsoles: ", steps)
                steps_end.append(steps)
                reward = -1
            else:
                reward = 0
            state = next_state



        # end_list.append(steps)
        # print("Steps to reach goal: ", steps)
    # print(len(end_list))
    # y = [np.polyval(curve, p) for p in end_list]
    # axis[r//subplot_size, r%subplot_size].hist(steps_end, color = 'g', orientation='horizontal')
    txt = f'Times reached goal vs times failed ratio: {len(steps_goal)/len(steps_end)}'
    print(txt)
    axis[r//subplot_size, r%subplot_size].hist(steps_goal, color = 'r', orientation='horizontal')
    axis[r//subplot_size, r%subplot_size].set_title(f'Epsilon = {r*10000}')
    axis[r//subplot_size, r%subplot_size].invert_yaxis()
    axis[r//subplot_size, r%subplot_size].axis(xmin=0,xmax=300)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.2)
# plt.savefig('ql-10-changing_no_of_episodes.png')

plt.show()
# Out:
# 10
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0
# Times reached goal vs times failed ratio: 0.0

# %%
x = defaultdict(lambda: {"a": np.zeros(env.action_space.n), "c": np.zeros(env.action_space.n)})
x[(0,1)]
# Out:
# {'a': array([0., 0., 0., 0.]), 'c': array([0., 0., 0., 0.])}
